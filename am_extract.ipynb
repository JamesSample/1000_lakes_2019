# %%
# %matplotlib inline

import pandas as pd
import nivapy3 as nivapy
import geopandas as gpd
import fiona
import matplotlib.pyplot as plt

# %% [markdown]
# # Extract AM data
#
# Getting station properties for the 2019 1000 Lakes project for Øyvind.

# %%
# Connect to db
eng = nivapy.da.connect()
# Out:
# Username:  ···
# Password:  ········
# Connection successful.

# %%
# Query projects
stn_df = nivapy.da.select_ndb_project_stations([12433],
                                               eng,
                                               drop_dups=True)
del stn_df['station_code'], stn_df['station_name'], stn_df['station_type']

# Add UTM Z33
stn_df = nivapy.spatial.wgs84_dd_to_utm(stn_df)

print(len(stn_df))
assert stn_df['station_id'].is_unique
stn_df.head()
# Out:
# 1002
#    station_id  longitude   latitude     utm_north       utm_east  utm_zone
# 0       26070  11.850274  59.808643  6.634299e+06  323345.999797        33
# 1       26071  11.563586  59.004423  6.545620e+06  302651.000302        33
# 2       26072  12.446711  60.060222  6.660863e+06  357866.000000        33
# 3       26073  11.842186  60.328578  6.692181e+06  325659.000153        33
# 4       26074  12.517008  60.590729  6.719770e+06  364003.000014        33

# %%
# Get stations properties
sql = """SELECT c.station_id,
           c.station_code,
           c.station_name,
           b.name,
           a.value_t
         FROM NIVADATABASE.STATION_ATTRIBUTES a,
           NIVADATABASE.STATION_ATTRIBUTE_DEFINITIONS b,
           NIVADATABASE.PROJECTS_STATIONS c
         WHERE c.project_id = 12433
         AND a.attribute_id  = b.attribute_id
         AND a.station_id    = c.station_id
         AND a.attribute_id IN (1,3,9,12,13,14,15,16,17,113,34,133,213,214)
      """

df = pd.read_sql(sql, eng)

# Reshape
df.set_index(['station_id', 'station_code', 'station_name', 'name'], inplace=True)
df = df.unstack('name')
df.reset_index(inplace=True)

# Tidy
df.sort_values('station_id', inplace=True)
df.index.name = ''
df.columns = list(df.columns.get_level_values(0)[:3]) + list(df.columns.get_level_values(1)[3:])
df.rename({'Areal':'Areal_km2'}, inplace=True, axis='columns')
df['Innsjønummer'] = df['Innsjønummer'].astype(int)

df.head()
# Out:
#    station_id station_code station_name Areal_km2     Fylke Fylkenummer  \
#
# 0       26070      221-1-2    Langtjern    0.0497  Akershus        0200
# 1       26071      101-2-7    Hokksjøen    0.1339   Østfold        0100
# 2       26072     402-2-13   Sætertjern    0.1196   Hedmark        0400
# 3       26073     419-1-25    Mjøgsjøen    0.0482   Hedmark        0400
# 4       26074      425-2-2      Kottern    0.1384   Hedmark        0400
#
#    Innsjønavn  Innsjønummer     Kommunenavn Kommunenummer Naturvern  \
#
# 0   LANGTJERN          3208  Aurskog-Høland          0221       NaN
# 1   HOKKSJØEN          3608          Halden          0101       NaN
# 2  SÆTERTJERN          4332     Kongsvinger          0402       NaN
# 3   MJØGSJØEN          4055        Sør-Odal          0419       NaN
# 4     KOTTERN          3794           Åsnes          0425       NaN
#
#   Naturvernform VannforekomstNavn
#
# 0           NaN               NaN
# 1           NaN               NaN
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN

# %%
# Read lakes dataset
gdb_path = r'../../NVEData.gdb'
gdf = gpd.read_file(gdb_path, layer='Innsjo')
gdf = gdf[['vatnLnr', 'hoyde_moh']]
gdf.rename({'vatnLnr':'Innsjønummer'}, inplace=True, axis='columns')
gdf.head()
# Out:
#    Innsjønummer  hoyde_moh
# 0        165333      -8888
# 1         56888        438
# 2        151207      -8888
# 3        192275      -8888
# 4         97273      -8888

# %%
df = pd.merge(df, gdf, how='left', on='Innsjønummer')
df.head()
# Out:
#    station_id station_code station_name Areal_km2     Fylke Fylkenummer  \
# 0       26070      221-1-2    Langtjern    0.0497  Akershus        0200
# 1       26071      101-2-7    Hokksjøen    0.1339   Østfold        0100
# 2       26072     402-2-13   Sætertjern    0.1196   Hedmark        0400
# 3       26073     419-1-25    Mjøgsjøen    0.0482   Hedmark        0400
# 4       26074      425-2-2      Kottern    0.1384   Hedmark        0400
#
#    Innsjønavn  Innsjønummer     Kommunenavn Kommunenummer Naturvern  \
# 0   LANGTJERN          3208  Aurskog-Høland          0221       NaN
# 1   HOKKSJØEN          3608          Halden          0101       NaN
# 2  SÆTERTJERN          4332     Kongsvinger          0402       NaN
# 3   MJØGSJØEN          4055        Sør-Odal          0419       NaN
# 4     KOTTERN          3794           Åsnes          0425       NaN
#
#   Naturvernform VannforekomstNavn  hoyde_moh
# 0           NaN               NaN      273.0
# 1           NaN               NaN      148.0
# 2           NaN               NaN      252.0
# 3           NaN               NaN      489.0
# 4           NaN               NaN      480.0

# %%
df = pd.merge(df, stn_df, how='left', on='station_id')
df.head()
# Out:
#    station_id station_code station_name Areal_km2     Fylke Fylkenummer  \
# 0       26070      221-1-2    Langtjern    0.0497  Akershus        0200
# 1       26071      101-2-7    Hokksjøen    0.1339   Østfold        0100
# 2       26072     402-2-13   Sætertjern    0.1196   Hedmark        0400
# 3       26073     419-1-25    Mjøgsjøen    0.0482   Hedmark        0400
# 4       26074      425-2-2      Kottern    0.1384   Hedmark        0400
#
#    Innsjønavn  Innsjønummer     Kommunenavn Kommunenummer Naturvern  \
# 0   LANGTJERN          3208  Aurskog-Høland          0221       NaN
# 1   HOKKSJØEN          3608          Halden          0101       NaN
# 2  SÆTERTJERN          4332     Kongsvinger          0402       NaN
# 3   MJØGSJØEN          4055        Sør-Odal          0419       NaN
# 4     KOTTERN          3794           Åsnes          0425       NaN
#
#   Naturvernform VannforekomstNavn  hoyde_moh  longitude   latitude  \
# 0           NaN               NaN      273.0  11.850274  59.808643
# 1           NaN               NaN      148.0  11.563586  59.004423
# 2           NaN               NaN      252.0  12.446711  60.060222
# 3           NaN               NaN      489.0  11.842186  60.328578
# 4           NaN               NaN      480.0  12.517008  60.590729
#
#       utm_north       utm_east  utm_zone
# 0  6.634299e+06  323345.999797        33
# 1  6.545620e+06  302651.000302        33
# 2  6.660863e+06  357866.000000        33
# 3  6.692181e+06  325659.000153        33
# 4  6.719770e+06  364003.000014        33

# %%
# Tidy
df = df[['station_id', 'station_code', 'station_name', 'longitude', 'latitude', 
         'utm_north', 'utm_east', 'utm_zone', 'Areal_km2', 'hoyde_moh', 
         'Innsjønavn', 'Innsjønummer', 'Fylke', 'Fylkenummer', 'Kommunenavn', 
         'Kommunenummer', 'Naturvern', 'Naturvernform', 'VannforekomstNavn']]
df.columns = [i.lower() for i in df.columns]

# Save 
df.to_csv('../../1000_Lakes_AM_Export_2019-09-09.csv', encoding='utf-8', index=False)
df.head()
# Out:
#    station_id station_code station_name  longitude   latitude     utm_north  \
# 0       26070      221-1-2    Langtjern  11.850274  59.808643  6.634299e+06
# 1       26071      101-2-7    Hokksjøen  11.563586  59.004423  6.545620e+06
# 2       26072     402-2-13   Sætertjern  12.446711  60.060222  6.660863e+06
# 3       26073     419-1-25    Mjøgsjøen  11.842186  60.328578  6.692181e+06
# 4       26074      425-2-2      Kottern  12.517008  60.590729  6.719770e+06
#
#         utm_east  utm_zone areal_km2  hoyde_moh  innsjønavn  innsjønummer  \
# 0  323345.999797        33    0.0497      273.0   LANGTJERN          3208
# 1  302651.000302        33    0.1339      148.0   HOKKSJØEN          3608
# 2  357866.000000        33    0.1196      252.0  SÆTERTJERN          4332
# 3  325659.000153        33    0.0482      489.0   MJØGSJØEN          4055
# 4  364003.000014        33    0.1384      480.0     KOTTERN          3794
#
#       fylke fylkenummer     kommunenavn kommunenummer naturvern naturvernform  \
# 0  Akershus        0200  Aurskog-Høland          0221       NaN           NaN
# 1   Østfold        0100          Halden          0101       NaN           NaN
# 2   Hedmark        0400     Kongsvinger          0402       NaN           NaN
# 3   Hedmark        0400        Sør-Odal          0419       NaN           NaN
# 4   Hedmark        0400           Åsnes          0425       NaN           NaN
#
#   vannforekomstnavn
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
